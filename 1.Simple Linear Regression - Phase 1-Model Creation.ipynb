# %%
# pandas is a libraries and it contains the functions realated to the database

# %%
import pandas as pd

# %%
# Dataset is assigned by calling the function read_csv() loaded into pandas

# %%
dataset = pd.read_csv("Salary_Data.csv")
dataset.head(3)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0

# %%
# split the input and output

# %%
independent = dataset[["YearsExperience"]] # the datsset collumn is assigned to independent variable
independent.head(3)
# Out:
#    YearsExperience
# 0              1.1
# 1              1.3
# 2              1.5

# %%
dependent = dataset[["Salary"]] # the datsset collumn is assigned to dependent variable
dataset.head(3)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0

# %%
# split the dataset as test set and train set

# %%
# Import the 'train_test_split' function from scikit-learn's 'model_selection
from sklearn.model_selection import train_test_split 

# train_test_split splits data into training and testing sets.
X_train, X_test, y_train, y_test = train_test_split(independant, dependant, test_size=0.30, random_state=0)

# %%
# Model Creation

# %%
# Import the LinearRegression class from scikit-learn's linear_model module.
from sklearn.linear_model import LinearRegression # procedure

# create a object from LinearRegression class
regressor = LinearRegression() # procedure

# create the model by training the data and using fit() method
regressor.fit(X_train,y_train) # substitutions / training phase
# Out:
# LinearRegression()

# %%
weight = regressor.coef_ # Finding weight
weight
# Out:
# array([[9360.26128619]])

# %%
bias = regressor.intercept_ # Finding bias
bias
# Out:
# array([26777.3913412])

# %%
# prediction

# %%
y_pred = regressor.predict(X_test) # predicted values is assigned to y_pred

# %%
from sklearn.metrics import r2_score # import r2_score function
r_score = r2_score(y_test, y_pred) # Evaluate by using r2_score fuction with y_test and y_pred

# %%
r_score
# Out:
# 0.9740993407213511

# %%
# saving finalized model

# %%
import pickle # import picle class
filename = "finalized_model_linear.sav" # finalized model name is assigned to filename variable

# %%
pickle.dump(regressor, open(filename, 'wb')) # save the model as a binary file

# %%
# load the previously saved model from binary file
loaded_model = pickle.load(open("finalized_model_linear.sav", 'rb'))

# %%
result = loaded_model.predict([[15]]) # make prediction by using pre trained loaded model
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[167181.3106341]])
